# %% [markdown]
# ### 1. Feature Extractor (Freeze) vs Fine-Tuning

# %%
# !python run.py --mode "freeze" --model "resnet50" --optimizer "adam" --lr 1e-3
# Out:
# [Train 1 / 5] Loss: 0.7544, Accuracy: 74.41%,  Time: 192.73s
# [Train 2 / 5] Loss: 0.6288, Accuracy: 78.36%,  Time: 192.60s
# [Train 3 / 5] Loss: 0.6056, Accuracy: 79.29%,  Time: 192.78s
# [Train 4 / 5] Loss: 0.5876, Accuracy: 79.66%,  Time: 192.16s
# [Train 5 / 5] Loss: 0.5730, Accuracy: 80.28%,  Time: 193.22s
# [Test] Loss: 0.5071, Accuracy: 82.71%

# %%
# !python run.py --mode "finetune" --model "resnet50" --optimizer "adam" --lr 1e-4
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 146MB/s]
# [Train 1 / 5] Loss: 0.3333, Accuracy: 89.11%,  Time: 615.18s
# [Train 2 / 5] Loss: 0.1602, Accuracy: 94.61%,  Time: 622.26s
# [Train 3 / 5] Loss: 0.1072, Accuracy: 96.40%,  Time: 623.64s
# [Train 4 / 5] Loss: 0.0880, Accuracy: 96.94%,  Time: 621.11s
# [Train 5 / 5] Loss: 0.0695, Accuracy: 97.65%,  Time: 622.35s
# [Test] Loss: 0.1787, Accuracy: 94.41%

# %% [markdown]
# ### 2. Data Augmentation

# %%
# !python run.py --mode "finetune" --model "resnet50" --optimizer "adam" --lr 1e-4 --epochs 10
# Out:
# [Train 1 / 10] Loss: 0.3333, Accuracy: 89.11%,  Time: 686.77s
# [Train 2 / 10] Loss: 0.1602, Accuracy: 94.61%,  Time: 702.96s
# [Train 3 / 10] Loss: 0.1072, Accuracy: 96.40%,  Time: 702.61s
# [Train 4 / 10] Loss: 0.0880, Accuracy: 96.94%,  Time: 703.61s
# [Train 5 / 10] Loss: 0.0695, Accuracy: 97.65%,  Time: 700.82s
# [Train 6 / 10] Loss: 0.0606, Accuracy: 97.95%,  Time: 701.25s
# [Train 7 / 10] Loss: 0.0558, Accuracy: 98.09%,  Time: 701.12s
# [Train 8 / 10] Loss: 0.0471, Accuracy: 98.41%,  Time: 701.30s
# [Train 9 / 10] Loss: 0.0444, Accuracy: 98.50%,  Time: 701.14s
# [Train 10 / 10] Loss: 0.0391, Accuracy: 98.71%,  Time: 700.73s
# [Test] Loss: 0.2306, Accuracy: 93.72%

# %%
# !python run.py --mode "finetune" --model "resnet50" --augmentation --optimizer "adam" --lr 1e-4 --epochs 10
# Out:
# [Train 1 / 10] Loss: 0.3599, Accuracy: 88.30%,  Time: 703.70s
# [Train 2 / 10] Loss: 0.2095, Accuracy: 92.99%,  Time: 701.69s
# [Train 3 / 10] Loss: 0.1668, Accuracy: 94.29%,  Time: 701.20s
# [Train 4 / 10] Loss: 0.1458, Accuracy: 95.06%,  Time: 695.25s
# [Train 5 / 10] Loss: 0.1185, Accuracy: 96.00%,  Time: 673.89s
# [Train 6 / 10] Loss: 0.1106, Accuracy: 96.22%,  Time: 673.34s
# [Train 7 / 10] Loss: 0.0961, Accuracy: 96.77%,  Time: 672.63s
# [Train 8 / 10] Loss: 0.0880, Accuracy: 96.96%,  Time: 672.36s
# [Train 9 / 10] Loss: 0.0809, Accuracy: 97.18%,  Time: 687.98s
# [Train 10 / 10] Loss: 0.0744, Accuracy: 97.42%,  Time: 700.85s
# [Test] Loss: 0.2149, Accuracy: 93.88%

# %% [markdown]
# ### 3. Optimizer

# %%
# !python run.py --mode "finetune" --model "resnet50" --optimizer "sgd" --lr 1e-2
# Out:
# [Train 1 / 5] Loss: 0.5585, Accuracy: 81.58%,  Time: 614.68s
# [Train 2 / 5] Loss: 0.2540, Accuracy: 91.51%,  Time: 613.95s
# [Train 3 / 5] Loss: 0.1686, Accuracy: 94.19%,  Time: 613.60s
# [Train 4 / 5] Loss: 0.1190, Accuracy: 95.97%,  Time: 614.21s
# [Train 5 / 5] Loss: 0.0976, Accuracy: 96.67%,  Time: 614.82s
# [Test] Loss: 0.2071, Accuracy: 93.58%

# %% [markdown]
# ### 4. Learning Rate Scheduler

# %%
# !python run.py --mode "finetune" --model "resnet50" --optimizer "adam" --lr 1e-4 --scheduler "steplr"
# Out:
# [Train 1 / 5] Loss: 0.3333, Accuracy: 89.11%,  Time: 623.62s
# [Train 2 / 5] Loss: 0.1602, Accuracy: 94.61%,  Time: 621.78s
# [Train 3 / 5] Loss: 0.0458, Accuracy: 98.62%,  Time: 621.52s
# [Train 4 / 5] Loss: 0.0170, Accuracy: 99.60%,  Time: 621.37s
# [Train 5 / 5] Loss: 0.0092, Accuracy: 99.87%,  Time: 620.72s
# [Test] Loss: 0.1041, Accuracy: 96.68%

# %%
# !python run.py --mode "finetune" --model "resnet50" --optimizer "adam" --lr 1e-4 --scheduler "cosinelr"
# Out:
# [Train 1 / 5] Loss: 0.3333, Accuracy: 89.11%,  Time: 624.04s
# [Train 2 / 5] Loss: 0.1465, Accuracy: 95.08%,  Time: 621.37s
# [Train 3 / 5] Loss: 0.0645, Accuracy: 97.91%,  Time: 622.21s
# [Train 4 / 5] Loss: 0.0228, Accuracy: 99.28%,  Time: 621.56s
# [Train 5 / 5] Loss: 0.0066, Accuracy: 99.86%,  Time: 621.77s
# [Test] Loss: 0.1146, Accuracy: 96.67%

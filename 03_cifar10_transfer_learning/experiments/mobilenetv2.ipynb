# %% [markdown]
# ### Manual MobileNetV2

# %%
# !python run.py --mode "manual" --model "mobilenetv2" --optimizer "adam" --lr 1e-3 --epochs 5
# Out:
# [Train 1 / 5] Loss: 1.6156, Accuracy: 40.43%,  Time: 59.00s
# [Train 2 / 5] Loss: 1.1933, Accuracy: 58.22%,  Time: 58.18s
# [Train 3 / 5] Loss: 0.9846, Accuracy: 66.05%,  Time: 57.48s
# [Train 4 / 5] Loss: 0.8370, Accuracy: 71.07%,  Time: 58.58s
# [Train 5 / 5] Loss: 0.7226, Accuracy: 75.34%,  Time: 58.88s
# [Test] Loss: 0.7607, Accuracy: 73.81%

# %%
# !python run.py --mode "manual" --model "mobilenetv2" --optimizer "adam" --lr 1e-3 --epochs 10
# Out:
# [Train 1 / 10] Loss: 1.6156, Accuracy: 40.43%,  Time: 59.92s
# [Train 2 / 10] Loss: 1.1933, Accuracy: 58.22%,  Time: 59.05s
# [Train 3 / 10] Loss: 0.9846, Accuracy: 66.05%,  Time: 59.52s
# [Train 4 / 10] Loss: 0.8370, Accuracy: 71.07%,  Time: 57.86s
# [Train 5 / 10] Loss: 0.7226, Accuracy: 75.34%,  Time: 58.75s
# [Train 6 / 10] Loss: 0.6407, Accuracy: 78.02%,  Time: 58.10s
# [Train 7 / 10] Loss: 0.5757, Accuracy: 80.19%,  Time: 60.22s
# [Train 8 / 10] Loss: 0.5200, Accuracy: 82.16%,  Time: 58.58s
# [Train 9 / 10] Loss: 0.4704, Accuracy: 83.95%,  Time: 57.86s
# [Train 10 / 10] Loss: 0.4246, Accuracy: 85.36%,  Time: 58.89s
# [Test] Loss: 0.6255, Accuracy: 79.03%

# %% [markdown]
# ### 0. Manual MobileNetV2

# %%
# !python run.py --mode "manual" --model "mobilenetv2_manual" --optimizer "adam" --lr 1e-3 --epochs 5
# Out:
# [Train 1 / 5] Loss: 1.6156, Accuracy: 40.43%,  Time: 56.79s
# [Train 2 / 5] Loss: 1.1933, Accuracy: 58.22%,  Time: 56.33s
# [Train 3 / 5] Loss: 0.9846, Accuracy: 66.05%,  Time: 56.91s
# [Train 4 / 5] Loss: 0.8370, Accuracy: 71.07%,  Time: 57.74s
# [Train 5 / 5] Loss: 0.7226, Accuracy: 75.34%,  Time: 56.72s
# [Test] Loss: 0.7607, Accuracy: 73.81%

# %%
# !python run.py --mode "manual" --model "mobilenetv2_manual" --optimizer "adam" --lr 1e-3 --epochs 10
# Out:
# [Train 1 / 10] Loss: 1.6156, Accuracy: 40.43%,  Time: 55.27s
# [Train 2 / 10] Loss: 1.1933, Accuracy: 58.22%,  Time: 55.08s
# [Train 3 / 10] Loss: 0.9846, Accuracy: 66.05%,  Time: 54.88s
# [Train 4 / 10] Loss: 0.8370, Accuracy: 71.07%,  Time: 54.70s
# [Train 5 / 10] Loss: 0.7226, Accuracy: 75.34%,  Time: 54.56s
# [Train 6 / 10] Loss: 0.6407, Accuracy: 78.02%,  Time: 54.48s
# [Train 7 / 10] Loss: 0.5757, Accuracy: 80.19%,  Time: 54.52s
# [Train 8 / 10] Loss: 0.5200, Accuracy: 82.16%,  Time: 55.76s
# [Train 9 / 10] Loss: 0.4704, Accuracy: 83.95%,  Time: 55.48s
# [Train 10 / 10] Loss: 0.4246, Accuracy: 85.36%,  Time: 56.71s
# [Test] Loss: 0.6255, Accuracy: 79.03%

# %% [markdown]
# ### 1. MobileNetV2 Transfer Learning: Feature Extraction vs. Fine-Tuning

# %%
# !python run.py --mode "freeze" --model "mobilenetv2" --optimizer "adam" --lr 1e-3 --epochs 5
# Out:
# [Train 1 / 5] Loss: 0.9341, Accuracy: 69.68%,  Time: 120.27s
# [Train 2 / 5] Loss: 0.7640, Accuracy: 73.59%,  Time: 118.26s
# [Train 3 / 5] Loss: 0.7390, Accuracy: 74.32%,  Time: 121.32s
# [Train 4 / 5] Loss: 0.7302, Accuracy: 74.66%,  Time: 117.28s
# [Train 5 / 5] Loss: 0.7321, Accuracy: 74.70%,  Time: 121.92s
# [Test] Loss: 0.6458, Accuracy: 78.05%

# %%
# !python run.py --mode "finetune" --model "mobilenetv2" --optimizer "adam" --lr 1e-4 --epochs 5
# Out:
# [Train 1 / 5] Loss: 0.4924, Accuracy: 84.29%,  Time: 243.97s
# [Train 2 / 5] Loss: 0.1879, Accuracy: 93.71%,  Time: 243.74s
# [Train 3 / 5] Loss: 0.1075, Accuracy: 96.39%,  Time: 243.50s
# [Train 4 / 5] Loss: 0.0671, Accuracy: 97.81%,  Time: 242.94s
# [Train 5 / 5] Loss: 0.0475, Accuracy: 98.41%,  Time: 243.86s
# [Test] Loss: 0.2330, Accuracy: 93.16%

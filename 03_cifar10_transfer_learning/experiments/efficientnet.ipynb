# %% [markdown]
# ### 0. Manual EfficientNet

# %%
# !python run.py --mode "manual" --model "efficientnet_manual" --optimizer "adam" --lr 1e-3 --epochs 5
# Out:
# [Train 1 / 5] Loss: 1.8250, Accuracy: 31.50%,  Time: 84.63s
# [Train 2 / 5] Loss: 1.5645, Accuracy: 42.24%,  Time: 83.87s
# [Train 3 / 5] Loss: 1.4540, Accuracy: 46.94%,  Time: 84.90s
# [Train 4 / 5] Loss: 1.3995, Accuracy: 49.19%,  Time: 85.28s
# [Train 5 / 5] Loss: 1.2406, Accuracy: 55.59%,  Time: 85.27s
# [Test] Loss: 1.1354, Accuracy: 60.29%

# %%
# !python run.py --mode "manual" --model "efficientnet_manual" --optimizer "adam" --lr 1e-3 --epochs 10
# Out:
# [Train 1 / 10] Loss: 1.8250, Accuracy: 31.50%,  Time: 84.69s
# [Train 2 / 10] Loss: 1.5645, Accuracy: 42.24%,  Time: 84.37s
# [Train 3 / 10] Loss: 1.4540, Accuracy: 46.94%,  Time: 84.73s
# [Train 4 / 10] Loss: 1.3995, Accuracy: 49.19%,  Time: 85.68s
# [Train 5 / 10] Loss: 1.2406, Accuracy: 55.59%,  Time: 85.60s
# [Train 6 / 10] Loss: 1.1104, Accuracy: 60.71%,  Time: 84.73s
# [Train 7 / 10] Loss: 1.0015, Accuracy: 64.99%,  Time: 84.83s
# [Train 8 / 10] Loss: 1.1453, Accuracy: 59.71%,  Time: 84.94s
# [Train 9 / 10] Loss: 1.0109, Accuracy: 64.70%,  Time: 85.02s
# [Train 10 / 10] Loss: 1.0066, Accuracy: 64.60%,  Time: 85.27s
# [Test] Loss: 1.1770, Accuracy: 59.10%

# %% [markdown]
# ### 1. EfficientNet Transfer Learning: Feature Extraction vs. Fine-Tuning

# %%
# !python run.py --mode "freeze" --model "efficientnet" --optimizer "adam" --lr 1e-3 --epochs 5
# Out:
# [Train 1 / 5] Loss: 0.8837, Accuracy: 71.52%,  Time: 127.97s
# [Train 2 / 5] Loss: 0.7255, Accuracy: 75.49%,  Time: 128.59s
# [Train 3 / 5] Loss: 0.7118, Accuracy: 75.75%,  Time: 128.40s
# [Train 4 / 5] Loss: 0.6981, Accuracy: 76.04%,  Time: 129.41s
# [Train 5 / 5] Loss: 0.6914, Accuracy: 76.32%,  Time: 124.73s
# [Test] Loss: 0.5631, Accuracy: 80.73%

# %%
# !python run.py --mode "finetune" --model "efficientnet" --optimizer "adam" --lr 1e-4 --epochs 5
# Out:
# [Train 1 / 5] Loss: 0.4021, Accuracy: 87.51%,  Time: 300.11s
# [Train 2 / 5] Loss: 0.1466, Accuracy: 95.13%,  Time: 300.95s
# [Train 3 / 5] Loss: 0.0870, Accuracy: 97.05%,  Time: 302.07s
# [Train 4 / 5] Loss: 0.0626, Accuracy: 97.79%,  Time: 302.28s
# [Train 5 / 5] Loss: 0.0462, Accuracy: 98.45%,  Time: 301.82s
# [Test] Loss: 0.1214, Accuracy: 96.57%

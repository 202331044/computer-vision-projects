# %%
# %cd /content/drive/MyDrive/Colab Notebooks/src
# Out:
# /content/drive/MyDrive/Colab Notebooks/src

# %%
# !python main.py --epochs 5 --lr 1e-2
# Out:
# src: tensor([3, 4, 5, 2])
# tgt: tensor([1, 3, 4, 5])
# label: tensor([3, 4, 5, 2])
# ---------epoch: 1---------
# loss: 3.1432 accuracy: 0.25
# ---------epoch: 2---------
# loss: 1.0681 accuracy: 0.75
# ---------epoch: 3---------
# loss: 0.9200 accuracy: 0.50
# ---------epoch: 4---------
# loss: 0.0421 accuracy: 1.00
# ---------epoch: 5---------
# loss: 0.0378 accuracy: 1.00
#
# ['나는', '밥을', '먹는다', '<EOS>']
# I eat rice

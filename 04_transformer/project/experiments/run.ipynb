# %%
# %matplotlib inline

# %%
# %run main.py --epochs 10
# Out:
# Epoch [1 / 10]
# Train Loss: 0.5916 Train Accuracy: 78.02%
# Val Loss: 0.3947 Val Accuracy: 86.03%
#
# Epoch [2 / 10]
# Train Loss: 0.3695 Train Accuracy: 87.24%
# Val Loss: 0.3508 Val Accuracy: 87.98%
#
# Epoch [3 / 10]
# Train Loss: 0.2996 Train Accuracy: 89.84%
# Val Loss: 0.3244 Val Accuracy: 89.27%
#
# Epoch [4 / 10]
# Train Loss: 0.2576 Train Accuracy: 91.26%
# Val Loss: 0.2850 Val Accuracy: 90.42%
#
# Epoch [5 / 10]
# Train Loss: 0.2208 Train Accuracy: 92.46%
# Val Loss: 0.2841 Val Accuracy: 90.70%
#
# Epoch [6 / 10]
# Train Loss: 0.1916 Train Accuracy: 93.46%
# Val Loss: 0.2768 Val Accuracy: 90.89%
#
# Epoch [7 / 10]
# Train Loss: 0.1644 Train Accuracy: 94.34%
# Val Loss: 0.2862 Val Accuracy: 91.31%
#
# Epoch [8 / 10]
# Train Loss: 0.1400 Train Accuracy: 95.13%
# Val Loss: 0.2973 Val Accuracy: 91.37%
#
# Epoch [9 / 10]
# Train Loss: 0.1192 Train Accuracy: 95.80%
# Val Loss: 0.3078 Val Accuracy: 91.56%
#
# Epoch [10 / 10]
# Train Loss: 0.1064 Train Accuracy: 96.31%
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/project/src
# Out:
# /content/drive/MyDrive/Colab Notebooks/project/src

# %%
# %matplotlib inline

# %% [markdown]
# ### 1. Baseline (N = 2, num_heads = 4)

# %%
# %run main.py --epochs 10 --nheads 4 --nlayers 2
# Out:
# Epoch [1 / 10]
# Train Loss: 0.5763 Train Accuracy: 78.57%
# Val Loss: 0.4362 Val Accuracy: 84.97%
#
# Epoch [2 / 10]
# Train Loss: 0.3596 Train Accuracy: 87.62%
# Val Loss: 0.3658 Val Accuracy: 87.48%
#
# Epoch [3 / 10]
# Train Loss: 0.2929 Train Accuracy: 90.06%
# Val Loss: 0.3029 Val Accuracy: 89.48%
#
# Epoch [4 / 10]
# Train Loss: 0.2485 Train Accuracy: 91.52%
# Val Loss: 0.3024 Val Accuracy: 90.03%
#
# Epoch [5 / 10]
# Train Loss: 0.2136 Train Accuracy: 92.76%
# Val Loss: 0.2723 Val Accuracy: 91.12%
#
# Epoch [6 / 10]
# Train Loss: 0.1839 Train Accuracy: 93.71%
# Val Loss: 0.2914 Val Accuracy: 91.06%
#
# Epoch [7 / 10]
# Train Loss: 0.1584 Train Accuracy: 94.48%
# Val Loss: 0.3068 Val Accuracy: 91.20%
#
# Epoch [8 / 10]
# Train Loss: 0.1347 Train Accuracy: 95.23%
# Val Loss: 0.3113 Val Accuracy: 91.42%
#
# Epoch [9 / 10]
# Train Loss: 0.1152 Train Accuracy: 95.93%
# Val Loss: 0.3232 Val Accuracy: 91.48%
#
# Epoch [10 / 10]
# Train Loss: 0.1041 Train Accuracy: 96.35%
# ...

# %% [markdown]
# ### 2. Encoder Depth Comparison
# - N = 1
# - num_heads = 4

# %%
# %run main.py --epochs 10 --nlayers 1
# Out:
# Epoch [1 / 10]
# Train Loss: 1.0733 Train Accuracy: 53.22%
# Val Loss: 0.8549 Val Accuracy: 66.22%
#
# Epoch [2 / 10]
# Train Loss: 0.8777 Train Accuracy: 64.75%
# Val Loss: 0.7653 Val Accuracy: 70.54%
#
# Epoch [3 / 10]
# Train Loss: 0.7971 Train Accuracy: 68.88%
# Val Loss: 0.7622 Val Accuracy: 70.86%
#
# Epoch [4 / 10]
# Train Loss: 0.7568 Train Accuracy: 70.45%
# Val Loss: 0.7164 Val Accuracy: 73.01%
#
# Epoch [5 / 10]
# Train Loss: 0.7121 Train Accuracy: 72.40%
# Val Loss: 0.6731 Val Accuracy: 74.64%
#
# Epoch [6 / 10]
# Train Loss: 0.6285 Train Accuracy: 76.56%
# Val Loss: 0.5842 Val Accuracy: 78.53%
#
# Epoch [7 / 10]
# Train Loss: 0.5872 Train Accuracy: 78.00%
# Val Loss: 0.5767 Val Accuracy: 78.85%
#
# Epoch [8 / 10]
# Train Loss: 0.5661 Train Accuracy: 78.75%
# Val Loss: 0.5556 Val Accuracy: 79.49%
#
# Epoch [9 / 10]
# Train Loss: 0.5431 Train Accuracy: 79.80%
# Val Loss: 0.5510 Val Accuracy: 79.65%
#
# Epoch [10 / 10]
# Train Loss: 0.5351 Train Accuracy: 79.99%
# ...

# %% [markdown]
# ### 2. Encoder Depth Comparison
# - N = 3
# - num_heads = 4

# %%
# %run main.py --epochs 10 --nlayers 3
# Out:
# Epoch [1 / 10]
# Train Loss: 0.5756 Train Accuracy: 78.27%
# Val Loss: 0.4115 Val Accuracy: 85.89%
#
# Epoch [2 / 10]
# Train Loss: 0.3731 Train Accuracy: 87.18%
# Val Loss: 0.3708 Val Accuracy: 87.14%
#
# Epoch [3 / 10]
# Train Loss: 0.3016 Train Accuracy: 89.77%
# Val Loss: 0.3580 Val Accuracy: 88.53%
#
# Epoch [4 / 10]
# Train Loss: 0.2532 Train Accuracy: 91.43%
# Val Loss: 0.2973 Val Accuracy: 89.88%
#
# Epoch [5 / 10]
# Train Loss: 0.2133 Train Accuracy: 92.79%
# Val Loss: 0.2941 Val Accuracy: 90.33%
#
# Epoch [6 / 10]
# Train Loss: 0.1769 Train Accuracy: 93.98%
# Val Loss: 0.3055 Val Accuracy: 90.42%
#
# Epoch [7 / 10]
# Train Loss: 0.1471 Train Accuracy: 95.00%
# Val Loss: 0.3111 Val Accuracy: 90.91%
#
# Epoch [8 / 10]
# Train Loss: 0.1174 Train Accuracy: 95.98%
# Val Loss: 0.3205 Val Accuracy: 91.13%
#
# Epoch [9 / 10]
# Train Loss: 0.0959 Train Accuracy: 96.67%
# Val Loss: 0.3425 Val Accuracy: 91.21%
#
# Epoch [10 / 10]
# Train Loss: 0.0799 Train Accuracy: 97.29%
# ...

# %% [markdown]
# ### 3. Attention Heads Comparison
# - N = 2
# - num_heads = 2

# %%
# %run main.py --epochs 10 --nheads 2
# Out:
# Epoch [1 / 10]
# Train Loss: 0.5932 Train Accuracy: 77.85%
# Val Loss: 0.3874 Val Accuracy: 86.59%
#
# Epoch [2 / 10]
# Train Loss: 0.3527 Train Accuracy: 87.88%
# Val Loss: 0.3291 Val Accuracy: 88.83%
#
# Epoch [3 / 10]
# Train Loss: 0.2855 Train Accuracy: 90.26%
# Val Loss: 0.3182 Val Accuracy: 89.23%
#
# Epoch [4 / 10]
# Train Loss: 0.2442 Train Accuracy: 91.66%
# Val Loss: 0.3131 Val Accuracy: 89.79%
#
# Epoch [5 / 10]
# Train Loss: 0.2112 Train Accuracy: 92.70%
# Val Loss: 0.3043 Val Accuracy: 89.69%
#
# Epoch [6 / 10]
# Train Loss: 0.1843 Train Accuracy: 93.57%
# Val Loss: 0.2852 Val Accuracy: 90.77%
#
# Epoch [7 / 10]
# Train Loss: 0.1607 Train Accuracy: 94.31%
# Val Loss: 0.2947 Val Accuracy: 90.97%
#
# Epoch [8 / 10]
# Train Loss: 0.1391 Train Accuracy: 95.10%
# Val Loss: 0.3068 Val Accuracy: 91.26%
#
# Epoch [9 / 10]
# Train Loss: 0.1243 Train Accuracy: 95.61%
# Val Loss: 0.3089 Val Accuracy: 91.38%
#
# Epoch [10 / 10]
# Train Loss: 0.1132 Train Accuracy: 95.99%
# ...

# %% [markdown]
# ### 4. Attention Heads Comparison
# - N = 2
# - num_heads = 8

# %%
# %run main.py --epochs 10 --nheads 8
# Out:
# Epoch [1 / 10]
# Train Loss: 0.5513 Train Accuracy: 79.45%
# Val Loss: 0.3910 Val Accuracy: 86.33%
#
# Epoch [2 / 10]
# Train Loss: 0.3646 Train Accuracy: 87.28%
# Val Loss: 0.3417 Val Accuracy: 87.96%
#
# Epoch [3 / 10]
# Train Loss: 0.3024 Train Accuracy: 89.71%
# Val Loss: 0.3123 Val Accuracy: 89.16%
#
# Epoch [4 / 10]
# Train Loss: 0.2593 Train Accuracy: 91.07%
# Val Loss: 0.2900 Val Accuracy: 90.08%
#
# Epoch [5 / 10]
# Train Loss: 0.2248 Train Accuracy: 92.26%
# Val Loss: 0.2847 Val Accuracy: 90.66%
#
# Epoch [6 / 10]
# Train Loss: 0.1935 Train Accuracy: 93.37%
# Val Loss: 0.3056 Val Accuracy: 90.48%
#
# Epoch [7 / 10]
# Train Loss: 0.1670 Train Accuracy: 94.20%
# Val Loss: 0.2834 Val Accuracy: 91.31%
#
# Epoch [8 / 10]
# Train Loss: 0.1401 Train Accuracy: 95.06%
# Val Loss: 0.3000 Val Accuracy: 91.05%
#
# Epoch [9 / 10]
# Train Loss: 0.1182 Train Accuracy: 95.87%
# Val Loss: 0.3134 Val Accuracy: 91.57%
#
# Epoch [10 / 10]
# Train Loss: 0.1028 Train Accuracy: 96.44%
# ...

# %%
# %matplotlib inline

# %%
# %run main.py --epochs 10
# Out:
# Epoch [1 / 10]
# Train Loss:0.5887 Train Accuracy:77.83
# Val Loss:0.3966 Val Accuracy:86.12
#
# Epoch [2 / 10]
# Train Loss:0.3625 Train Accuracy:87.59
# Val Loss:0.3371 Val Accuracy:88.51
#
# Epoch [3 / 10]
# Train Loss:0.2973 Train Accuracy:89.91
# Val Loss:0.3004 Val Accuracy:89.63
#
# Epoch [4 / 10]
# Train Loss:0.2541 Train Accuracy:91.33
# Val Loss:0.2844 Val Accuracy:90.22
#
# Epoch [5 / 10]
# Train Loss:0.2199 Train Accuracy:92.56
# Val Loss:0.3021 Val Accuracy:90.33
#
# Epoch [6 / 10]
# Train Loss:0.1907 Train Accuracy:93.38
# Val Loss:0.2904 Val Accuracy:90.83
#
# Epoch [7 / 10]
# Train Loss:0.1636 Train Accuracy:94.34
# Val Loss:0.3082 Val Accuracy:90.88
#
# Epoch [8 / 10]
# Train Loss:0.1402 Train Accuracy:95.11
# Val Loss:0.3006 Val Accuracy:91.18
#
# Epoch [9 / 10]
# Train Loss:0.1195 Train Accuracy:95.80
# Val Loss:0.3235 Val Accuracy:91.30
#
# Epoch [10 / 10]
# Train Loss:0.1052 Train Accuracy:96.31
# Val Loss:0.3308 Val Accuracy:91.47

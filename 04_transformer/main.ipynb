# %%
# %cd /content/drive/MyDrive/Colab Notebooks/04_transformer
# Out:
# /content/drive/MyDrive/Colab Notebooks/04_transformer

# %%
# !python run.py --epochs 5 --lr 1e-2
# Out:
# src: tensor([3, 4, 5, 2])
# tgt: tensor([1, 3, 4, 5])
# label: tensor([3, 4, 5, 2])
# ---------epoch: 1---------
# loss: 3.9201 accuracy: 0.00
# ---------epoch: 2---------
# loss: 1.2723 accuracy: 0.50
# ---------epoch: 3---------
# loss: 0.4827 accuracy: 1.00
# ---------epoch: 4---------
# loss: 0.0636 accuracy: 1.00
# ---------epoch: 5---------
# loss: 0.5184 accuracy: 0.75
#
# ['나는', '밥을', '먹는다', '<EOS>']
# I eat rice

# %%
# !python run.py --epochs 5 --lr 1e-2
# Out:
# src: tensor([3, 4, 5, 2])
# tgt: tensor([1, 3, 4, 5])
# label: tensor([3, 4, 5, 2])
# ---------epoch: 1---------
# loss: 4.6451 accuracy: 0.00
# ---------epoch: 2---------
# loss: 1.4407 accuracy: 0.50
# ---------epoch: 3---------
# loss: 0.7534 accuracy: 0.50
# ---------epoch: 4---------
# loss: 0.1831 accuracy: 1.00
# ---------epoch: 5---------
# loss: 0.0763 accuracy: 1.00

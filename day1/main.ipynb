# %%
# !python day1.py
# Out:
# epoch: 1 loss: 0.3402
# epoch: 2 loss: 0.1568
# epoch: 3 loss: 0.1093
# Accuracy:  96.68%

# %%
# !python day1_task.py
# Out:
# epoch: 1 loss:  0.3537
# epoch: 2 loss:  0.1602
# epoch: 3 loss:  0.1093
# epoch: 4 loss:  0.0823
# epoch: 5 loss:  0.0642
# Accuracy:  97.46%

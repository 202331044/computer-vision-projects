# %% [markdown]
# ### Step 3. Dropout

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

# %% [markdown]
# ### Step 4. Dropout + Increased Early Stopping Patience

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

# %% [markdown]
# ### Step 15. Data Augmentation

# %%
# !python src/run.py --model "task10_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4689 Train Acc: 44.93%
# Val Loss: 1.2587 Val Acc: 55.42%
# -------------------------
# Epoch: 2
# Train Loss: 1.0585 Train Acc: 61.99%
# Val Loss: 1.1567 Val Acc: 60.47%
# -------------------------
# Epoch: 3
# Train Loss: 0.8713 Train Acc: 69.15%
# Val Loss: 0.8625 Val Acc: 70.30%
# -------------------------
# Epoch: 4
# Train Loss: 0.7552 Train Acc: 73.69%
# Val Loss: 0.7573 Val Acc: 74.02%
# -------------------------
# Epoch: 5
# Train Loss: 0.6750 Train Acc: 76.61%
# Val Loss: 0.7185 Val Acc: 75.47%
# -------------------------
# Epoch: 6
# Train Loss: 0.6170 Train Acc: 78.70%
# Val Loss: 0.7150 Val Acc: 75.95%
# -------------------------
# Epoch: 7
# Train Loss: 0.5736 Train Acc: 80.20%
# Val Loss: 0.6137 Val Acc: 78.65%
# -------------------------
# Epoch: 8
# Train Loss: 0.5312 Train Acc: 81.81%
# Val Loss: 0.6055 Val Acc: 79.13%
# -------------------------
# Epoch: 9
# Train Loss: 0.5018 Train Acc: 82.62%
# ...

# %% [markdown]
# ### Step 16. Data Augmentation (RandAugment)

# %%
# !python src/run.py --model "task10_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.6128 Train Acc: 39.71%
# Val Loss: 1.3616 Val Acc: 51.82%
# -------------------------
# Epoch: 2
# Train Loss: 1.2100 Train Acc: 56.12%
# Val Loss: 1.0764 Val Acc: 62.22%
# -------------------------
# Epoch: 3
# Train Loss: 1.0388 Train Acc: 62.96%
# Val Loss: 0.8504 Val Acc: 70.10%
# -------------------------
# Epoch: 4
# Train Loss: 0.9131 Train Acc: 67.69%
# Val Loss: 0.8598 Val Acc: 71.72%
# -------------------------
# Epoch: 5
# Train Loss: 0.8271 Train Acc: 71.14%
# Val Loss: 0.7264 Val Acc: 74.88%
# -------------------------
# Epoch: 6
# Train Loss: 0.7693 Train Acc: 73.17%
# Val Loss: 0.6928 Val Acc: 76.13%
# -------------------------
# Epoch: 7
# Train Loss: 0.7188 Train Acc: 75.04%
# Val Loss: 0.7148 Val Acc: 76.31%
# -------------------------
# Epoch: 8
# Train Loss: 0.6843 Train Acc: 76.51%
# Val Loss: 0.5931 Val Acc: 79.31%
# -------------------------
# Epoch: 9
# Train Loss: 0.6455 Train Acc: 77.73%
# ...

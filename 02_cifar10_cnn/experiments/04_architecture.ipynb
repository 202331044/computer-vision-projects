# %% [markdown]
# ### Step 5. Hidden Layer Addition

# %%
# !python run.py --model "task2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4645 Train Acc: 46.45%
# Val Loss: 1.2480 Val Acc: 55.79%
# -------------------------
# Epoch: 2
# Train Loss: 1.0962 Train Acc: 61.01%
# Val Loss: 1.0433 Val Acc: 63.03%
# -------------------------
# Epoch: 3
# Train Loss: 0.9238 Train Acc: 67.23%
# Val Loss: 0.9113 Val Acc: 67.79%
# -------------------------
# Epoch: 4
# Train Loss: 0.8066 Train Acc: 71.67%
# Val Loss: 0.8819 Val Acc: 69.25%
# -------------------------
# Epoch: 5
# Train Loss: 0.7126 Train Acc: 74.89%
# Val Loss: 0.8560 Val Acc: 70.84%
# -------------------------
# Epoch: 6
# Train Loss: 0.6387 Train Acc: 77.66%
# Val Loss: 0.8292 Val Acc: 71.24%
# -------------------------
# Epoch: 7
# Train Loss: 0.5676 Train Acc: 80.30%
# Val Loss: 0.8492 Val Acc: 71.71%
# -------------------------
# Epoch: 8
# Train Loss: 0.5094 Train Acc: 82.26%
# Val Loss: 0.8751 Val Acc: 71.93%
# -------------------------
# Epoch: 9
# Train Loss: 0.4583 Train Acc: 83.88%
# ...

# %% [markdown]
# ###  Step 6. Pooling Reordering (Conv → Conv → Pool)

# %%
# !python run.py --model "task3" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4532 Train Acc: 47.12%
# Val Loss: 1.2174 Val Acc: 57.05%
# -------------------------
# Epoch: 2
# Train Loss: 1.0531 Train Acc: 62.52%
# Val Loss: 0.9980 Val Acc: 65.23%
# -------------------------
# Epoch: 3
# Train Loss: 0.8782 Train Acc: 68.93%
# Val Loss: 0.8588 Val Acc: 70.43%
# -------------------------
# Epoch: 4
# Train Loss: 0.7647 Train Acc: 73.29%
# Val Loss: 0.8558 Val Acc: 70.39%
# -------------------------
# Epoch: 5
# Train Loss: 0.6789 Train Acc: 76.16%
# Val Loss: 0.8280 Val Acc: 71.73%
# -------------------------
# Epoch: 6
# Train Loss: 0.6054 Train Acc: 78.97%
# Val Loss: 0.8000 Val Acc: 72.61%
# -------------------------
# Epoch: 7
# Train Loss: 0.5429 Train Acc: 80.83%
# Val Loss: 0.7978 Val Acc: 73.08%
# -------------------------
# Epoch: 8
# Train Loss: 0.4841 Train Acc: 82.97%
# Val Loss: 0.8150 Val Acc: 72.98%
# -------------------------
# Epoch: 9
# Train Loss: 0.4378 Train Acc: 84.38%
# ...

# %% [markdown]
# ### Step 8. Combined Architecture Update (Multiple Changes)

# %%
# !python run.py --model "task5" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3090 Train Acc: 52.50%
# Val Loss: 1.0205 Val Acc: 64.60%
# -------------------------
# Epoch: 2
# Train Loss: 0.8755 Train Acc: 69.14%
# Val Loss: 0.8337 Val Acc: 69.80%
# -------------------------
# Epoch: 3
# Train Loss: 0.7282 Train Acc: 74.59%
# Val Loss: 0.7707 Val Acc: 73.11%
# -------------------------
# Epoch: 4
# Train Loss: 0.6330 Train Acc: 78.09%
# Val Loss: 0.8080 Val Acc: 72.08%
# -------------------------
# Epoch: 5
# Train Loss: 0.5610 Train Acc: 80.53%
# Val Loss: 0.7210 Val Acc: 75.68%
# -------------------------
# Epoch: 6
# Train Loss: 0.5013 Train Acc: 82.38%
# Val Loss: 0.7432 Val Acc: 74.54%
# -------------------------
# Epoch: 7
# Train Loss: 0.4533 Train Acc: 84.17%
# Val Loss: 0.6273 Val Acc: 79.35%
# -------------------------
# Epoch: 8
# Train Loss: 0.4034 Train Acc: 86.11%
# Val Loss: 0.6074 Val Acc: 79.46%
# -------------------------
# Epoch: 9
# Train Loss: 0.3606 Train Acc: 87.36%
# ...

# %% [markdown]
# ### Step 11. Residual Block: With vs Without Skip Connection

# %%
# !python run.py --model "task8_1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3925 Train Acc: 48.06%
# Val Loss: 1.1579 Val Acc: 57.54%
# -------------------------
# Epoch: 2
# Train Loss: 1.0079 Train Acc: 63.54%
# Val Loss: 0.9319 Val Acc: 66.51%
# -------------------------
# Epoch: 3
# Train Loss: 0.8423 Train Acc: 70.21%
# Val Loss: 0.8492 Val Acc: 69.71%
# -------------------------
# Epoch: 4
# Train Loss: 0.7274 Train Acc: 74.48%
# Val Loss: 0.7307 Val Acc: 74.16%
# -------------------------
# Epoch: 5
# Train Loss: 0.6405 Train Acc: 77.58%
# Val Loss: 0.6608 Val Acc: 77.00%
# -------------------------
# Epoch: 6
# Train Loss: 0.5749 Train Acc: 80.15%
# Val Loss: 0.6574 Val Acc: 76.84%
# -------------------------
# Epoch: 7
# Train Loss: 0.5258 Train Acc: 81.64%
# Val Loss: 0.6364 Val Acc: 77.97%
# -------------------------
# Epoch: 8
# Train Loss: 0.4822 Train Acc: 83.22%
# Val Loss: 0.5983 Val Acc: 79.41%
# -------------------------
# Epoch: 9
# Train Loss: 0.4440 Train Acc: 84.58%
# ...

# %%
# !python run.py --model "task8_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3772 Train Acc: 48.83%
# Val Loss: 1.1304 Val Acc: 59.01%
# -------------------------
# Epoch: 2
# Train Loss: 0.9984 Train Acc: 64.32%
# Val Loss: 0.9648 Val Acc: 65.87%
# -------------------------
# Epoch: 3
# Train Loss: 0.8422 Train Acc: 69.98%
# Val Loss: 1.0584 Val Acc: 62.99%
# -------------------------
# Epoch: 4
# Train Loss: 0.7224 Train Acc: 74.61%
# Val Loss: 0.7490 Val Acc: 73.77%
# -------------------------
# Epoch: 5
# Train Loss: 0.6353 Train Acc: 77.70%
# Val Loss: 0.7041 Val Acc: 76.00%
# -------------------------
# Epoch: 6
# Train Loss: 0.5615 Train Acc: 80.54%
# Val Loss: 0.8013 Val Acc: 73.58%
# -------------------------
# Epoch: 7
# Train Loss: 0.5074 Train Acc: 82.39%
# Val Loss: 0.7080 Val Acc: 75.96%
# -------------------------
# Epoch: 8
# Train Loss: 0.4621 Train Acc: 83.91%
# Val Loss: 0.5698 Val Acc: 81.00%
# -------------------------
# Epoch: 9
# Train Loss: 0.4184 Train Acc: 85.25%
# ...

# %% [markdown]
# ### Step 14. Double Residual Block per Stage

# %%
# !python src/run.py --model "task10_1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.6357 Train Acc: 36.94%
# Val Loss: 1.4475 Val Acc: 45.60%
# -------------------------
# Epoch: 2
# Train Loss: 1.2456 Train Acc: 54.12%
# Val Loss: 1.3130 Val Acc: 53.25%
# -------------------------
# Epoch: 3
# Train Loss: 1.0300 Train Acc: 62.83%
# Val Loss: 1.1323 Val Acc: 59.51%
# -------------------------
# Epoch: 4
# Train Loss: 0.8951 Train Acc: 68.15%
# Val Loss: 0.8544 Val Acc: 69.63%
# -------------------------
# Epoch: 5
# Train Loss: 0.8031 Train Acc: 71.83%
# Val Loss: 0.8341 Val Acc: 70.55%
# -------------------------
# Epoch: 6
# Train Loss: 0.7363 Train Acc: 74.08%
# Val Loss: 0.8891 Val Acc: 69.56%
# -------------------------
# Epoch: 7
# Train Loss: 0.6773 Train Acc: 76.17%
# Val Loss: 0.7043 Val Acc: 75.20%
# -------------------------
# Epoch: 8
# Train Loss: 0.6292 Train Acc: 78.09%
# Val Loss: 0.6728 Val Acc: 76.53%
# -------------------------
# Epoch: 9
# Train Loss: 0.5859 Train Acc: 79.74%
# ...

# %%
# !python src/run.py --model "task10_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# 100% 170M/170M [00:14<00:00, 11.8MB/s]
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3916 Train Acc: 48.16%
# Val Loss: 1.2437 Val Acc: 54.61%
# -------------------------
# Epoch: 2
# Train Loss: 0.9783 Train Acc: 64.83%
# Val Loss: 0.9824 Val Acc: 64.71%
# -------------------------
# Epoch: 3
# Train Loss: 0.7938 Train Acc: 71.83%
# Val Loss: 0.7904 Val Acc: 72.85%
# -------------------------
# Epoch: 4
# Train Loss: 0.6690 Train Acc: 76.79%
# Val Loss: 0.6428 Val Acc: 77.51%
# -------------------------
# Epoch: 5
# Train Loss: 0.5875 Train Acc: 79.50%
# Val Loss: 0.6061 Val Acc: 79.21%
# -------------------------
# Epoch: 6
# Train Loss: 0.5226 Train Acc: 81.87%
# Val Loss: 0.5887 Val Acc: 79.89%
# -------------------------
# Epoch: 7
# Train Loss: 0.4658 Train Acc: 83.69%
# Val Loss: 0.5813 Val Acc: 80.30%
# -------------------------
# Epoch: 8
# Train Loss: 0.4272 Train Acc: 85.19%
# Val Loss: 0.5631 Val Acc: 80.89%
# -------------------------
# Epoch: 9
# ...

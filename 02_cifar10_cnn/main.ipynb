# %%
# !python run.py --model "baseline"
# Out:
# Epoch: 1
# Train Loss: 1.4075 Train Acc: 49.18%
# Val Loss: 1.1698 Val Acc: 58.60%
# Epoch: 2
# Train Loss: 1.0526 Train Acc: 62.69%
# Val Loss: 1.0280 Val Acc: 63.82%
# Epoch: 3
# Train Loss: 0.8996 Train Acc: 68.41%
# Val Loss: 0.9565 Val Acc: 66.90%

# %%
# !python run.py --model "task1" --epochs 10
# Out:
# Epoch: 1
# Train Loss: 1.4251 Train Acc: 48.34%
# Val Loss: 1.1128 Val Acc: 60.46%
# Epoch: 2
# Train Loss: 1.0145 Train Acc: 63.92%
# Val Loss: 0.9592 Val Acc: 66.60%
# Epoch: 3
# Train Loss: 0.8349 Train Acc: 70.39%
# Val Loss: 0.8846 Val Acc: 69.30%
# Epoch: 4
# Train Loss: 0.7092 Train Acc: 75.00%
# Val Loss: 0.8920 Val Acc: 69.94%
# Epoch: 5
# Train Loss: 0.6168 Train Acc: 78.11%
# Val Loss: 0.8675 Val Acc: 71.06%
# Epoch: 6
# Train Loss: 0.5326 Train Acc: 81.18%
# Val Loss: 0.9214 Val Acc: 71.36%
# Epoch: 7
# Train Loss: 0.4530 Train Acc: 83.90%
# Val Loss: 0.9405 Val Acc: 71.28%
# Epoch: 8
# Train Loss: 0.3930 Train Acc: 85.95%
# Val Loss: 0.9984 Val Acc: 71.38%
# Epoch: 9
# Train Loss: 0.3375 Train Acc: 87.99%
# Val Loss: 1.0902 Val Acc: 71.60%
# Epoch: 10
# Train Loss: 0.2900 Train Acc: 89.68%
# Val Loss: 1.1662 Val Acc: 71.94%

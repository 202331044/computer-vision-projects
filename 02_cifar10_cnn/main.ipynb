# %%
# !python day2.py
# Out:
# epoch: 1 loss:  1.3760
# epoch: 2 loss:  1.0329
# epoch: 3 loss:  0.8878
# Accuracy: 66.93

# %%
# !python 02_task.py
# Out:
# epoch: 1 loss:  1.4046
# epoch: 2 loss:  0.9871
# epoch: 3 loss:  0.8084
# Accuracy: 70.91

# %% [markdown]
# ### Baseline Model

# %%
# !python run.py --model "baseline" --epochs 10 --batch_size 32 --optimizer "Adam"
# Out:
# -------fold 1-------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Step 1. Early Stopping

# %%
# !python run.py --model "baseline" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Step 2. Increase Early Stopping Patience

# %%
# !python run.py --model "baseline" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Step 3. Dropout

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

# %% [markdown]
# ### Step 4. Dropout + Increased Early Stopping Patience

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

# %% [markdown]
# ### Step 5. Hidden Layer Addition

# %%
# !python run.py --model "task2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4645 Train Acc: 46.45%
# Val Loss: 1.2480 Val Acc: 55.79%
# -------------------------
# Epoch: 2
# Train Loss: 1.0962 Train Acc: 61.01%
# Val Loss: 1.0433 Val Acc: 63.03%
# -------------------------
# Epoch: 3
# Train Loss: 0.9238 Train Acc: 67.23%
# Val Loss: 0.9113 Val Acc: 67.79%
# -------------------------
# Epoch: 4
# Train Loss: 0.8066 Train Acc: 71.67%
# Val Loss: 0.8819 Val Acc: 69.25%
# -------------------------
# Epoch: 5
# Train Loss: 0.7126 Train Acc: 74.89%
# Val Loss: 0.8560 Val Acc: 70.84%
# -------------------------
# Epoch: 6
# Train Loss: 0.6387 Train Acc: 77.66%
# Val Loss: 0.8292 Val Acc: 71.24%
# -------------------------
# Epoch: 7
# Train Loss: 0.5676 Train Acc: 80.30%
# Val Loss: 0.8492 Val Acc: 71.71%
# -------------------------
# Epoch: 8
# Train Loss: 0.5094 Train Acc: 82.26%
# Val Loss: 0.8751 Val Acc: 71.93%
# -------------------------
# Epoch: 9
# Train Loss: 0.4583 Train Acc: 83.88%
# ...

# %% [markdown]
# ###  Step 6. Pooling Reordering (Conv → Conv → Pool)

# %%
# !python run.py --model "task3" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4532 Train Acc: 47.12%
# Val Loss: 1.2174 Val Acc: 57.05%
# -------------------------
# Epoch: 2
# Train Loss: 1.0531 Train Acc: 62.52%
# Val Loss: 0.9980 Val Acc: 65.23%
# -------------------------
# Epoch: 3
# Train Loss: 0.8782 Train Acc: 68.93%
# Val Loss: 0.8588 Val Acc: 70.43%
# -------------------------
# Epoch: 4
# Train Loss: 0.7647 Train Acc: 73.29%
# Val Loss: 0.8558 Val Acc: 70.39%
# -------------------------
# Epoch: 5
# Train Loss: 0.6789 Train Acc: 76.16%
# Val Loss: 0.8280 Val Acc: 71.73%
# -------------------------
# Epoch: 6
# Train Loss: 0.6054 Train Acc: 78.97%
# Val Loss: 0.8000 Val Acc: 72.61%
# -------------------------
# Epoch: 7
# Train Loss: 0.5429 Train Acc: 80.83%
# Val Loss: 0.7978 Val Acc: 73.08%
# -------------------------
# Epoch: 8
# Train Loss: 0.4841 Train Acc: 82.97%
# Val Loss: 0.8150 Val Acc: 72.98%
# -------------------------
# Epoch: 9
# Train Loss: 0.4378 Train Acc: 84.38%
# ...

# %% [markdown]
# ### Step 7. Batch Normalization

# %%
# !python run.py --model "task4" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.2764 Train Acc: 54.19%
# Val Loss: 1.1210 Val Acc: 61.49%
# -------------------------
# Epoch: 2
# Train Loss: 0.9356 Train Acc: 67.09%
# Val Loss: 0.8906 Val Acc: 69.33%
# -------------------------
# Epoch: 3
# Train Loss: 0.8168 Train Acc: 71.30%
# Val Loss: 0.7939 Val Acc: 72.25%
# -------------------------
# Epoch: 4
# Train Loss: 0.7387 Train Acc: 73.99%
# Val Loss: 0.7338 Val Acc: 74.11%
# -------------------------
# Epoch: 5
# Train Loss: 0.6731 Train Acc: 76.58%
# Val Loss: 0.7777 Val Acc: 73.01%
# -------------------------
# Epoch: 6
# Train Loss: 0.6280 Train Acc: 77.82%
# Val Loss: 0.8064 Val Acc: 71.96%
# -------------------------
# Epoch: 7
# Train Loss: 0.5778 Train Acc: 79.68%
# Val Loss: 0.7536 Val Acc: 73.82%
# -------------------------
# Epoch: 8
# Train Loss: 0.5382 Train Acc: 81.08%
# Val Loss: 0.7366 Val Acc: 74.77%
# -------------------------
# Epoch: 9
# Train Loss: 0.5049 Train Acc: 82.17%
# ...

# %% [markdown]
# ### Step 8. Combined Architecture Update (Multiple Changes)

# %%
# !python run.py --model "task5" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3090 Train Acc: 52.50%
# Val Loss: 1.0205 Val Acc: 64.60%
# -------------------------
# Epoch: 2
# Train Loss: 0.8755 Train Acc: 69.14%
# Val Loss: 0.8337 Val Acc: 69.80%
# -------------------------
# Epoch: 3
# Train Loss: 0.7282 Train Acc: 74.59%
# Val Loss: 0.7707 Val Acc: 73.11%
# -------------------------
# Epoch: 4
# Train Loss: 0.6330 Train Acc: 78.09%
# Val Loss: 0.8080 Val Acc: 72.08%
# -------------------------
# Epoch: 5
# Train Loss: 0.5610 Train Acc: 80.53%
# Val Loss: 0.7210 Val Acc: 75.68%
# -------------------------
# Epoch: 6
# Train Loss: 0.5013 Train Acc: 82.38%
# Val Loss: 0.7432 Val Acc: 74.54%
# -------------------------
# Epoch: 7
# Train Loss: 0.4533 Train Acc: 84.17%
# Val Loss: 0.6273 Val Acc: 79.35%
# -------------------------
# Epoch: 8
# Train Loss: 0.4034 Train Acc: 86.11%
# Val Loss: 0.6074 Val Acc: 79.46%
# -------------------------
# Epoch: 9
# Train Loss: 0.3606 Train Acc: 87.36%
# ...

# %% [markdown]
# ### Step 9. AdaptiveMaxPool → AdaptiveAvgPool

# %%
# !python run.py --model "task6" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.2970 Train Acc: 52.60%
# Val Loss: 1.2223 Val Acc: 58.04%
# -------------------------
# Epoch: 2
# Train Loss: 0.9198 Train Acc: 67.34%
# Val Loss: 0.9145 Val Acc: 67.96%
# -------------------------
# Epoch: 3
# Train Loss: 0.7862 Train Acc: 72.41%
# Val Loss: 0.8927 Val Acc: 69.35%
# -------------------------
# Epoch: 4
# Train Loss: 0.6988 Train Acc: 75.48%
# Val Loss: 0.7315 Val Acc: 74.38%
# -------------------------
# Epoch: 5
# Train Loss: 0.6293 Train Acc: 77.81%
# Val Loss: 0.7144 Val Acc: 74.48%
# -------------------------
# Epoch: 6
# Train Loss: 0.5751 Train Acc: 79.92%
# Val Loss: 0.6903 Val Acc: 76.15%
# -------------------------
# Epoch: 7
# Train Loss: 0.5307 Train Acc: 81.23%
# Val Loss: 0.6464 Val Acc: 77.51%
# -------------------------
# Epoch: 8
# Train Loss: 0.4924 Train Acc: 82.97%
# Val Loss: 0.5838 Val Acc: 79.69%
# -------------------------
# Epoch: 9
# Train Loss: 0.4545 Train Acc: 83.85%
# ...

# %% [markdown]
# ### Step 10. Global Average Pooling (Adaptive)

# %%
# !python run.py --model "task7" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4270 Train Acc: 47.20%
# Val Loss: 1.1955 Val Acc: 56.99%
# -------------------------
# Epoch: 2
# Train Loss: 1.1003 Train Acc: 60.54%
# Val Loss: 1.2352 Val Acc: 56.18%
# -------------------------
# Epoch: 3
# Train Loss: 0.9827 Train Acc: 64.98%
# Val Loss: 1.0835 Val Acc: 61.72%
# -------------------------
# Epoch: 4
# Train Loss: 0.9027 Train Acc: 67.78%
# Val Loss: 0.9186 Val Acc: 67.61%
# -------------------------
# Epoch: 5
# Train Loss: 0.8412 Train Acc: 70.20%
# Val Loss: 0.8405 Val Acc: 70.14%
# -------------------------
# Epoch: 6
# Train Loss: 0.7848 Train Acc: 72.26%
# Val Loss: 0.8285 Val Acc: 70.65%
# -------------------------
# Epoch: 7
# Train Loss: 0.7356 Train Acc: 73.89%
# Val Loss: 0.8492 Val Acc: 70.80%
# -------------------------
# Epoch: 8
# Train Loss: 0.6941 Train Acc: 75.69%
# Val Loss: 0.7511 Val Acc: 73.24%
# -------------------------
# Epoch: 9
# Train Loss: 0.6579 Train Acc: 76.75%
# ...

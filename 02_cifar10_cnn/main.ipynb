# %%
# %cd /content/drive/MyDrive/Colab Notebooks/02_cifar10_cnn
# Out:
# /content/drive/MyDrive/Colab Notebooks/02_cifar10_cnn

# %% [markdown]
# ### Step 11. Residual Block (No Skip Connection vs Skip Connection)

# %%
# !python run.py --model "task8_1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3925 Train Acc: 48.06%
# Val Loss: 1.1579 Val Acc: 57.54%
# -------------------------
# Epoch: 2
# Train Loss: 1.0079 Train Acc: 63.54%
# Val Loss: 0.9319 Val Acc: 66.51%
# -------------------------
# Epoch: 3
# Train Loss: 0.8423 Train Acc: 70.21%
# Val Loss: 0.8492 Val Acc: 69.71%
# -------------------------
# Epoch: 4
# Train Loss: 0.7274 Train Acc: 74.48%
# Val Loss: 0.7307 Val Acc: 74.16%
# -------------------------
# Epoch: 5
# Train Loss: 0.6405 Train Acc: 77.58%
# Val Loss: 0.6608 Val Acc: 77.00%
# -------------------------
# Epoch: 6
# Train Loss: 0.5749 Train Acc: 80.15%
# Val Loss: 0.6574 Val Acc: 76.84%
# -------------------------
# Epoch: 7
# Train Loss: 0.5258 Train Acc: 81.64%
# Val Loss: 0.6364 Val Acc: 77.97%
# -------------------------
# Epoch: 8
# Train Loss: 0.4822 Train Acc: 83.22%
# Val Loss: 0.5983 Val Acc: 79.41%
# -------------------------
# Epoch: 9
# Train Loss: 0.4440 Train Acc: 84.58%
# ...

# %%
# !python run.py --model "task8_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3772 Train Acc: 48.83%
# Val Loss: 1.1304 Val Acc: 59.01%
# -------------------------
# Epoch: 2
# Train Loss: 0.9984 Train Acc: 64.32%
# Val Loss: 0.9648 Val Acc: 65.87%
# -------------------------
# Epoch: 3
# Train Loss: 0.8422 Train Acc: 69.98%
# Val Loss: 1.0584 Val Acc: 62.99%
# -------------------------
# Epoch: 4
# Train Loss: 0.7224 Train Acc: 74.61%
# Val Loss: 0.7490 Val Acc: 73.77%
# -------------------------
# Epoch: 5
# Train Loss: 0.6353 Train Acc: 77.70%
# Val Loss: 0.7041 Val Acc: 76.00%
# -------------------------
# Epoch: 6
# Train Loss: 0.5615 Train Acc: 80.54%
# Val Loss: 0.8013 Val Acc: 73.58%
# -------------------------
# Epoch: 7
# Train Loss: 0.5074 Train Acc: 82.39%
# Val Loss: 0.7080 Val Acc: 75.96%
# -------------------------
# Epoch: 8
# Train Loss: 0.4621 Train Acc: 83.91%
# Val Loss: 0.5698 Val Acc: 81.00%
# -------------------------
# Epoch: 9
# Train Loss: 0.4184 Train Acc: 85.25%
# ...

# %% [markdown]
# ### Step 12. Convolution bias = False

# %%
# !python run.py --model "task8_1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3753 Train Acc: 48.81%
# Val Loss: 1.1571 Val Acc: 57.86%
# -------------------------
# Epoch: 2
# Train Loss: 0.9985 Train Acc: 64.01%
# Val Loss: 1.1437 Val Acc: 59.68%
# -------------------------
# Epoch: 3
# Train Loss: 0.8343 Train Acc: 70.46%
# Val Loss: 0.9450 Val Acc: 66.63%
# -------------------------
# Epoch: 4
# Train Loss: 0.7149 Train Acc: 74.89%
# Val Loss: 0.6860 Val Acc: 76.20%
# -------------------------
# Epoch: 5
# Train Loss: 0.6254 Train Acc: 78.18%
# Val Loss: 0.6709 Val Acc: 76.39%
# -------------------------
# Epoch: 6
# Train Loss: 0.5631 Train Acc: 80.26%
# Val Loss: 0.7105 Val Acc: 75.29%
# -------------------------
# Epoch: 7
# Train Loss: 0.5131 Train Acc: 82.10%
# Val Loss: 0.5838 Val Acc: 79.87%
# -------------------------
# Epoch: 8
# Train Loss: 0.4739 Train Acc: 83.38%
# Val Loss: 0.6590 Val Acc: 77.77%
# -------------------------
# Epoch: 9
# Train Loss: 0.4330 Train Acc: 84.71%
# ...

# %%
# !python run.py --model "task8_2" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.3658 Train Acc: 49.38%
# Val Loss: 1.0974 Val Acc: 59.43%
# -------------------------
# Epoch: 2
# Train Loss: 0.9805 Train Acc: 64.76%
# Val Loss: 1.3003 Val Acc: 54.85%
# -------------------------
# Epoch: 3
# Train Loss: 0.8227 Train Acc: 70.62%
# Val Loss: 0.9802 Val Acc: 65.27%
# -------------------------
# Epoch: 4
# Train Loss: 0.7021 Train Acc: 75.42%
# Val Loss: 0.7424 Val Acc: 74.04%
# -------------------------
# Epoch: 5
# Train Loss: 0.6177 Train Acc: 78.21%
# Val Loss: 0.6273 Val Acc: 78.35%
# -------------------------
# Epoch: 6
# Train Loss: 0.5471 Train Acc: 81.03%
# Val Loss: 0.6620 Val Acc: 76.52%
# -------------------------
# Epoch: 7
# Train Loss: 0.4908 Train Acc: 82.75%
# Val Loss: 0.5890 Val Acc: 79.14%
# -------------------------
# Epoch: 8
# Train Loss: 0.4471 Train Acc: 84.45%
# Val Loss: 0.5662 Val Acc: 80.11%
# -------------------------
# Epoch: 9
# Train Loss: 0.4056 Train Acc: 85.88%
# ...

# %% [markdown]
# ### Step 13. Remove Pooling + Apply Stride

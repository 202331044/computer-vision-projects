# %%
# !python run.py --model "baseline"
# Out:
# Epoch: 1
# Train Loss: 1.4018 Train Acc: 49.62%
# Val Loss: 1.1277 Val Acc: 59.54%
# Epoch: 2
# Train Loss: 1.0452 Train Acc: 63.09%
# Val Loss: 1.0226 Val Acc: 63.58%
# Epoch: 3
# Train Loss: 0.8974 Train Acc: 68.33%
# Val Loss: 0.9125 Val Acc: 67.28%

# %%
# !python run.py --model "task1"
# Out:
# Epoch: 1
# Train Loss: 1.4442 Train Acc: 47.28%
# Val Loss: 1.1496 Val Acc: 59.10%
# Epoch: 2
# Train Loss: 1.0340 Train Acc: 63.44%
# Val Loss: 0.9467 Val Acc: 67.28%
# Epoch: 3
# Train Loss: 0.8639 Train Acc: 69.65%
# Val Loss: 0.9045 Val Acc: 67.90%

# %%
# !python run.py --model "task1" --epochs 10
# Out:
# Epoch: 1
# Train Loss: 1.4224 Train Acc: 48.30%
# Val Loss: 1.1348 Val Acc: 60.04%
# Epoch: 2
# Train Loss: 1.0086 Train Acc: 64.38%
# Val Loss: 0.9173 Val Acc: 67.60%
# Epoch: 3
# Train Loss: 0.8318 Train Acc: 70.80%
# Val Loss: 0.8575 Val Acc: 70.16%
# Epoch: 4
# Train Loss: 0.7124 Train Acc: 75.19%
# Val Loss: 0.8183 Val Acc: 71.68%
# Epoch: 5
# Train Loss: 0.6283 Train Acc: 78.00%
# Val Loss: 0.8029 Val Acc: 72.16%
# Epoch: 6
# Train Loss: 0.5484 Train Acc: 80.72%
# Val Loss: 0.8244 Val Acc: 72.78%
# Epoch: 7
# Train Loss: 0.4837 Train Acc: 83.02%
# Val Loss: 0.9497 Val Acc: 70.82%
# Epoch: 8
# Train Loss: 0.4323 Train Acc: 84.50%
# Val Loss: 0.9398 Val Acc: 71.94%
# Epoch: 9
# Train Loss: 0.3709 Train Acc: 86.69%
# Val Loss: 0.9537 Val Acc: 71.36%
# Epoch: 10
# Train Loss: 0.3256 Train Acc: 88.35%
# Val Loss: 0.9534 Val Acc: 72.66%

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 64 --optimizer "SGD"
# Out:
# Epoch: 1
# Train Loss: 2.3032 Train Acc: 9.99%
# Val Loss: 2.3025 Val Acc: 10.00%
# Epoch: 2
# Train Loss: 2.3017 Train Acc: 10.02%
# Val Loss: 2.3009 Val Acc: 10.06%
# Epoch: 3
# Train Loss: 2.2999 Train Acc: 10.52%
# Val Loss: 2.2990 Val Acc: 11.10%
# Epoch: 4
# Train Loss: 2.2978 Train Acc: 12.29%
# Val Loss: 2.2965 Val Acc: 13.56%
# Epoch: 5
# Train Loss: 2.2947 Train Acc: 16.54%
# Val Loss: 2.2928 Val Acc: 19.00%
# Epoch: 6
# Train Loss: 2.2898 Train Acc: 21.22%
# Val Loss: 2.2866 Val Acc: 21.30%
# Epoch: 7
# Train Loss: 2.2810 Train Acc: 21.80%
# Val Loss: 2.2746 Val Acc: 19.82%
# Epoch: 8
# Train Loss: 2.2622 Train Acc: 20.20%
# Val Loss: 2.2470 Val Acc: 19.68%
# Epoch: 9
# Train Loss: 2.2168 Train Acc: 20.60%
# Val Loss: 2.1805 Val Acc: 20.96%
# Epoch: 10
# Train Loss: 2.1338 Train Acc: 22.94%
# Val Loss: 2.0960 Val Acc: 23.80%
# Epoch: 11
# Train Loss: 2.0627 Train Acc: 25.36%
# Val Loss: 2.0375 Val Acc: 26.62%
# Epoch: 12
# Train Loss: 2.0128 Train Acc: 27.31%
# ...

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 64 --optimizer "Adam"
# Out:
# Epoch: 1
# Train Loss: 1.5230 Train Acc: 44.82%
# Val Loss: 1.2928 Val Acc: 53.02%
# Epoch: 2
# Train Loss: 1.1341 Train Acc: 59.69%
# Val Loss: 1.0507 Val Acc: 61.94%
# Epoch: 3
# Train Loss: 0.9434 Train Acc: 66.59%
# Val Loss: 0.9481 Val Acc: 66.10%
# Epoch: 4
# Train Loss: 0.8126 Train Acc: 71.54%
# Val Loss: 0.8594 Val Acc: 70.02%
# Epoch: 5
# Train Loss: 0.7180 Train Acc: 74.62%
# Val Loss: 0.8369 Val Acc: 71.26%
# Epoch: 6
# Train Loss: 0.6422 Train Acc: 77.36%
# Val Loss: 0.8219 Val Acc: 71.72%
# Epoch: 7
# Train Loss: 0.5736 Train Acc: 79.76%
# Val Loss: 0.8906 Val Acc: 70.20%
# Epoch: 8
# Train Loss: 0.5231 Train Acc: 81.50%
# Val Loss: 0.8109 Val Acc: 72.16%
# Epoch: 9
# Train Loss: 0.4605 Train Acc: 83.50%
# Val Loss: 0.8510 Val Acc: 72.96%
# Epoch: 10
# Train Loss: 0.4107 Train Acc: 85.23%
# Val Loss: 0.8973 Val Acc: 72.48%
# Epoch: 11
# Train Loss: 0.3631 Train Acc: 87.28%
# Val Loss: 0.9294 Val Acc: 72.16%
# Epoch: 12
# Train Loss: 0.3198 Train Acc: 88.57%
# ...

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 64 --optimizer "AdamW"
# Out:
# Epoch: 1
# Train Loss: 1.4858 Train Acc: 45.94%
# Val Loss: 1.1905 Val Acc: 57.28%
# Epoch: 2
# Train Loss: 1.0892 Train Acc: 61.17%
# Val Loss: 1.0024 Val Acc: 64.00%
# Epoch: 3
# Train Loss: 0.9113 Train Acc: 68.04%
# Val Loss: 0.8798 Val Acc: 69.18%
# Epoch: 4
# Train Loss: 0.7898 Train Acc: 72.55%
# Val Loss: 0.8426 Val Acc: 70.18%
# Epoch: 5
# Train Loss: 0.6947 Train Acc: 75.69%
# Val Loss: 0.8636 Val Acc: 70.16%
# Epoch: 6
# Train Loss: 0.6199 Train Acc: 78.32%
# Val Loss: 0.8466 Val Acc: 70.96%
# Epoch: 7
# Train Loss: 0.5461 Train Acc: 80.93%
# Val Loss: 0.8139 Val Acc: 72.20%
# Epoch: 8
# Train Loss: 0.4785 Train Acc: 83.17%
# Val Loss: 0.8136 Val Acc: 73.18%
# Epoch: 9
# Train Loss: 0.4213 Train Acc: 85.02%
# Val Loss: 0.8645 Val Acc: 73.72%
# Epoch: 10
# Train Loss: 0.3656 Train Acc: 87.02%
# Val Loss: 0.9709 Val Acc: 72.36%
# Epoch: 11
# Train Loss: 0.3122 Train Acc: 88.84%
# Val Loss: 0.9715 Val Acc: 72.58%
# Epoch: 12
# Train Loss: 0.2744 Train Acc: 90.06%
# ...

# %%
# !python run.py --model "task1" --batch_size 64 --epochs 100 --optimizer "Momentum"
# Out:
# Epoch: 1
# Train Loss: 2.2683 Train Acc: 16.64%
# Val Loss: 2.1355 Val Acc: 24.64%
# Epoch: 2
# Train Loss: 1.9519 Train Acc: 29.18%
# Val Loss: 1.8263 Val Acc: 33.96%
# Epoch: 3
# Train Loss: 1.7098 Train Acc: 37.42%
# Val Loss: 1.6134 Val Acc: 40.38%
# Epoch: 4
# Train Loss: 1.5707 Train Acc: 42.82%
# Val Loss: 1.5393 Val Acc: 44.30%
# Epoch: 5
# Train Loss: 1.4676 Train Acc: 46.99%
# Val Loss: 1.4065 Val Acc: 49.92%
# Epoch: 6
# Train Loss: 1.3805 Train Acc: 50.46%
# Val Loss: 1.3457 Val Acc: 51.20%
# Epoch: 7
# Train Loss: 1.3158 Train Acc: 52.89%
# Val Loss: 1.3483 Val Acc: 51.72%
# Epoch: 8
# Train Loss: 1.2575 Train Acc: 55.33%
# Val Loss: 1.2190 Val Acc: 56.66%
# Epoch: 9
# Train Loss: 1.1948 Train Acc: 57.54%
# Val Loss: 1.1730 Val Acc: 58.26%
# Epoch: 10
# Train Loss: 1.1431 Train Acc: 59.61%
# Val Loss: 1.1276 Val Acc: 60.22%
# Epoch: 11
# Train Loss: 1.0905 Train Acc: 61.36%
# Val Loss: 1.1428 Val Acc: 59.02%
# Epoch: 12
# Train Loss: 1.0506 Train Acc: 63.10%
# ...

# %%
#SGD learing rate: 0.001->0.01(basic) & add weight decay
# !python run.py --model "task1" --optimizer "SGD" --batch_size 64 --epochs 100
# Out:
# Epoch: 1
# Train Loss: 2.3038 Train Acc: 9.88%
# Val Loss: 2.3031 Val Acc: 11.98%
# Epoch: 2
# Train Loss: 2.3024 Train Acc: 12.72%
# Val Loss: 2.3018 Val Acc: 13.34%
# Epoch: 3
# Train Loss: 2.3011 Train Acc: 13.80%
# Val Loss: 2.3004 Val Acc: 14.58%
# Epoch: 4
# Train Loss: 2.2997 Train Acc: 15.10%
# Val Loss: 2.2988 Val Acc: 15.50%
# Epoch: 5
# Train Loss: 2.2979 Train Acc: 16.31%
# Val Loss: 2.2967 Val Acc: 16.40%
# Epoch: 6
# Train Loss: 2.2954 Train Acc: 17.17%
# Val Loss: 2.2937 Val Acc: 16.92%
# Epoch: 7
# Train Loss: 2.2916 Train Acc: 18.14%
# Val Loss: 2.2889 Val Acc: 18.70%
# Epoch: 8
# Train Loss: 2.2849 Train Acc: 19.97%
# Val Loss: 2.2799 Val Acc: 19.94%
# Epoch: 9
# Train Loss: 2.2711 Train Acc: 20.67%
# Val Loss: 2.2597 Val Acc: 20.16%
# Epoch: 10
# Train Loss: 2.2376 Train Acc: 20.61%
# Val Loss: 2.2102 Val Acc: 20.32%
# Epoch: 11
# Train Loss: 2.1707 Train Acc: 21.15%
# Val Loss: 2.1372 Val Acc: 21.64%
# Epoch: 12
# Train Loss: 2.1043 Train Acc: 23.19%
# ...

# %%
#stratifeid cross validation(k = 5)
# !python run.py --model "task1" --optimizer "AdamW" --batch_size 64 --epochs 100
# Out:
# Epoch: 1
# Train Loss: 1.5270 Train Acc: 44.41%
# Val Loss: 1.2798 Val Acc: 54.05%
# ---------------------------------------------------
# Epoch: 2
# Train Loss: 1.1270 Train Acc: 60.03%
# Val Loss: 1.0414 Val Acc: 62.78%
# ---------------------------------------------------
# Epoch: 3
# Train Loss: 0.9315 Train Acc: 67.12%
# Val Loss: 0.9449 Val Acc: 66.42%
# ---------------------------------------------------
# Epoch: 4
# Train Loss: 0.8063 Train Acc: 71.75%
# Val Loss: 0.8700 Val Acc: 69.17%
# ---------------------------------------------------
# Epoch: 5
# Train Loss: 0.7099 Train Acc: 74.96%
# Val Loss: 0.8678 Val Acc: 70.25%
# ---------------------------------------------------
# Epoch: 6
# Train Loss: 0.6259 Train Acc: 77.97%
# Val Loss: 0.8427 Val Acc: 71.34%
# ---------------------------------------------------
# Epoch: 7
# Train Loss: 0.5463 Train Acc: 80.84%
# Val Loss: 0.8918 Val Acc: 71.10%
# ---------------------------------------------------
# Epoch: 8
# ...

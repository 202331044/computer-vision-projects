# %% [markdown]
# ### Baseline Model

# %%
# !python run.py --model "baseline" --epochs 10 --batch_size 32 --optimizer "Adam"
# Out:
# -------fold 1-------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Early Stopping

# %%
# !python run.py --model "baseline" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Increase Early Stopping Patience

# %%
# !python run.py --model "baseline" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.4230 Train Acc: 48.61%
# Val Loss: 1.2591 Val Acc: 55.74%
# -------------------------
# Epoch: 2
# Train Loss: 1.0951 Train Acc: 60.90%
# Val Loss: 1.0614 Val Acc: 62.69%
# -------------------------
# Epoch: 3
# Train Loss: 0.9435 Train Acc: 66.45%
# Val Loss: 0.9592 Val Acc: 66.54%
# -------------------------
# Epoch: 4
# Train Loss: 0.8426 Train Acc: 70.36%
# Val Loss: 0.9468 Val Acc: 67.34%
# -------------------------
# Epoch: 5
# Train Loss: 0.7549 Train Acc: 73.34%
# Val Loss: 0.9095 Val Acc: 68.46%
# -------------------------
# Epoch: 6
# Train Loss: 0.6838 Train Acc: 76.02%
# Val Loss: 0.9183 Val Acc: 69.02%
# -------------------------
# Epoch: 7
# Train Loss: 0.6126 Train Acc: 78.33%
# Val Loss: 0.9292 Val Acc: 69.42%
# -------------------------
# Epoch: 8
# Train Loss: 0.5476 Train Acc: 80.78%
# Val Loss: 0.9431 Val Acc: 69.23%
# -------------------------
# Epoch: 9
# Train Loss: 0.4837 Train Acc: 82.84%
# ...

# %% [markdown]
# ### Dropout

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

# %% [markdown]
# ### Dropout + Increased Early Stopping Patience

# %%
# !python run.py --model "task1" --epochs 100 --batch_size 32 --optimizer "Adam" --early_stopping --patience 10
# Out:
# --------fold 1--------
# Epoch: 1
# Train Loss: 1.5860 Train Acc: 41.84%
# Val Loss: 1.3422 Val Acc: 51.57%
# -------------------------
# Epoch: 2
# Train Loss: 1.3035 Train Acc: 53.12%
# Val Loss: 1.1442 Val Acc: 59.32%
# -------------------------
# Epoch: 3
# Train Loss: 1.1798 Train Acc: 57.87%
# Val Loss: 1.0446 Val Acc: 62.85%
# -------------------------
# Epoch: 4
# Train Loss: 1.0941 Train Acc: 60.99%
# Val Loss: 1.0107 Val Acc: 64.02%
# -------------------------
# Epoch: 5
# Train Loss: 1.0388 Train Acc: 63.03%
# Val Loss: 0.9726 Val Acc: 66.06%
# -------------------------
# Epoch: 6
# Train Loss: 0.9806 Train Acc: 64.98%
# Val Loss: 0.9448 Val Acc: 66.73%
# -------------------------
# Epoch: 7
# Train Loss: 0.9363 Train Acc: 66.56%
# Val Loss: 0.9455 Val Acc: 67.10%
# -------------------------
# Epoch: 8
# Train Loss: 0.9060 Train Acc: 67.69%
# Val Loss: 0.8977 Val Acc: 68.50%
# -------------------------
# Epoch: 9
# Train Loss: 0.8639 Train Acc: 69.12%
# ...

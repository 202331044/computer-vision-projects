# %% [markdown]
# ### Baseline Model

# %%
# !python run.py --epochs 10 --batch_size 32 --model "baseline" --optimizer "Adam"
# Out:
# --------fold 1--------
# epoch: 1
# Train Loss: 0.3154 Train Acc: 91.24%
# Val Loss: 0.1753 Val Acc: 94.94%
# -------------------------
# epoch: 2
# Train Loss: 0.1390 Train Acc: 95.93%
# Val Loss: 0.1288 Val Acc: 96.28%
# -------------------------
# epoch: 3
# Train Loss: 0.0957 Train Acc: 97.10%
# Val Loss: 0.1084 Val Acc: 96.83%
# -------------------------
# epoch: 4
# Train Loss: 0.0696 Train Acc: 97.90%
# Val Loss: 0.0986 Val Acc: 97.26%
# -------------------------
# epoch: 5
# Train Loss: 0.0549 Train Acc: 98.34%
# Val Loss: 0.0981 Val Acc: 97.22%
# -------------------------
# epoch: 6
# Train Loss: 0.0434 Train Acc: 98.65%
# Val Loss: 0.0967 Val Acc: 97.22%
# -------------------------
# epoch: 7
# Train Loss: 0.0342 Train Acc: 98.95%
# Val Loss: 0.0902 Val Acc: 97.33%
# -------------------------
# epoch: 8
# Train Loss: 0.0266 Train Acc: 99.19%
# Val Loss: 0.0927 Val Acc: 97.47%
# -------------------------
# epoch: 9
# Train Loss: 0.0226 Train Acc: 99.30%
# ...

# %% [markdown]
# ### Hidden Layer Size Improvement

# %%
#Hidden layer size: 128 → 256
# !python run.py --epochs 10 --batch_size 32 --model "task1" --optimizer "Adam"
# Out:
# --------fold 1--------
# epoch: 1
# Train Loss: 0.2823 Train Acc: 91.97%
# Val Loss: 0.1500 Val Acc: 95.60%
# -------------------------
# epoch: 2
# Train Loss: 0.1137 Train Acc: 96.59%
# Val Loss: 0.1108 Val Acc: 96.78%
# -------------------------
# epoch: 3
# Train Loss: 0.0749 Train Acc: 97.73%
# Val Loss: 0.0946 Val Acc: 97.12%
# -------------------------
# epoch: 4
# Train Loss: 0.0522 Train Acc: 98.38%
# Val Loss: 0.0869 Val Acc: 97.46%
# -------------------------
# epoch: 5
# Train Loss: 0.0385 Train Acc: 98.80%
# Val Loss: 0.0926 Val Acc: 97.39%
# -------------------------
# epoch: 6
# Train Loss: 0.0287 Train Acc: 99.09%
# Val Loss: 0.0920 Val Acc: 97.42%
# -------------------------
# epoch: 7
# Train Loss: 0.0220 Train Acc: 99.33%
# Val Loss: 0.0874 Val Acc: 97.59%
# -------------------------
# epoch: 8
# Train Loss: 0.0170 Train Acc: 99.43%
# Val Loss: 0.1010 Val Acc: 97.62%
# -------------------------
# epoch: 9
# Train Loss: 0.0152 Train Acc: 99.50%
# ...

# %% [markdown]
# ### Early Stopping

# %%
# !python run.py --epochs 100 --batch_size 32 --model "task1" --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# epoch: 1
# Train Loss: 0.2823 Train Acc: 91.97%
# Val Loss: 0.1500 Val Acc: 95.60%
# -------------------------
# epoch: 2
# Train Loss: 0.1137 Train Acc: 96.59%
# Val Loss: 0.1108 Val Acc: 96.78%
# -------------------------
# epoch: 3
# Train Loss: 0.0749 Train Acc: 97.73%
# Val Loss: 0.0946 Val Acc: 97.12%
# -------------------------
# epoch: 4
# Train Loss: 0.0522 Train Acc: 98.38%
# Val Loss: 0.0869 Val Acc: 97.46%
# -------------------------
# epoch: 5
# Train Loss: 0.0385 Train Acc: 98.80%
# Val Loss: 0.0926 Val Acc: 97.39%
# -------------------------
# epoch: 6
# Train Loss: 0.0287 Train Acc: 99.09%
# Val Loss: 0.0920 Val Acc: 97.42%
# -------------------------
# epoch: 7
# Train Loss: 0.0220 Train Acc: 99.33%
# Val Loss: 0.0874 Val Acc: 97.59%
# -------------------------
# epoch: 8
# Train Loss: 0.0170 Train Acc: 99.43%
# Val Loss: 0.1010 Val Acc: 97.62%
# -------------------------
# epoch: 9
# Train Loss: 0.0152 Train Acc: 99.50%
# ...

# %% [markdown]
# ### Dropout

# %%
# !python run.py --epochs 100 --batch_size 32 --model "task2" --optimizer "Adam" --early_stopping --patience 5
# Out:
# --------fold 1--------
# epoch: 1
# Train Loss: 0.3173 Train Acc: 90.86%
# Val Loss: 0.1580 Val Acc: 95.37%
# -------------------------
# epoch: 2
# Train Loss: 0.1467 Train Acc: 95.57%
# Val Loss: 0.1150 Val Acc: 96.55%
# -------------------------
# epoch: 3
# Train Loss: 0.1075 Train Acc: 96.76%
# Val Loss: 0.0971 Val Acc: 97.11%
# -------------------------
# epoch: 4
# Train Loss: 0.0874 Train Acc: 97.31%
# Val Loss: 0.0881 Val Acc: 97.42%
# -------------------------
# epoch: 5
# Train Loss: 0.0734 Train Acc: 97.65%
# Val Loss: 0.0882 Val Acc: 97.49%
# -------------------------
# epoch: 6
# Train Loss: 0.0623 Train Acc: 98.03%
# Val Loss: 0.0770 Val Acc: 97.74%
# -------------------------
# epoch: 7
# Train Loss: 0.0553 Train Acc: 98.16%
# Val Loss: 0.0797 Val Acc: 97.70%
# -------------------------
# epoch: 8
# Train Loss: 0.0484 Train Acc: 98.39%
# Val Loss: 0.0822 Val Acc: 97.67%
# -------------------------
# epoch: 9
# Train Loss: 0.0436 Train Acc: 98.55%
# ...

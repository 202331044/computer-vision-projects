# %%
# !python run.py --epochs 3 --batch_size 64 --model "baseline"
# Out:
# /content/drive/MyDrive/Colab Notebooks/01_mnist_mlp
# 100% 9.91M/9.91M [00:00<00:00, 114MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 62.7MB/s]
# 100% 1.65M/1.65M [00:00<00:00, 80.3MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 12.4MB/s]
# epoch: 1 loss: 0.3470
# epoch: 2 loss: 0.1584
# epoch: 3 loss: 0.1100
# Accuracy:  96.92%

# %%
# !python run.py --epochs 5 --batch_size 128 --model "task1"
# Out:
# epoch: 1 loss: 0.3588
# epoch: 2 loss: 0.1523
# epoch: 3 loss: 0.1047
# epoch: 4 loss: 0.0780
# epoch: 5 loss: 0.0611
# Accuracy:  97.45%

# %%
#cross-validation, early stopping
# !python run.py --epochs 100 --batch_size 64 --model "task1" --optimizer "Adam"
# Out:
# --------fold 1--------
# epoch: 1
# Train Loss: 0.3364 Train Acc: 90.83%
# Val Loss: 0.1996 Val Acc: 94.01%
# --------------------------
# epoch: 2
# Train Loss: 0.1469 Train Acc: 95.68%
# Val Loss: 0.1339 Val Acc: 96.23%
# --------------------------
# epoch: 3
# Train Loss: 0.0960 Train Acc: 97.20%
# Val Loss: 0.1033 Val Acc: 97.02%
# --------------------------
# epoch: 4
# Train Loss: 0.0703 Train Acc: 97.96%
# Val Loss: 0.1020 Val Acc: 96.94%
# --------------------------
# epoch: 5
# Train Loss: 0.0526 Train Acc: 98.43%
# Val Loss: 0.0855 Val Acc: 97.50%
# --------------------------
# epoch: 6
# Train Loss: 0.0410 Train Acc: 98.79%
# Val Loss: 0.0834 Val Acc: 97.58%
# --------------------------
# epoch: 7
# Train Loss: 0.0303 Train Acc: 99.12%
# Val Loss: 0.0817 Val Acc: 97.71%
# --------------------------
# epoch: 8
# Train Loss: 0.0241 Train Acc: 99.31%
# Val Loss: 0.0831 Val Acc: 97.72%
# --------------------------
# epoch: 9
# Train Loss: 0.0206 Train Acc: 99.40%
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/05_vit_transformer
# Out:
# /content/drive/MyDrive/Colab Notebooks/05_vit_transformer

# %%
# %run main.py --epochs 20
# Out:
# Epoch: 1
# Train Loss: 1.6967, Train Accuracy: 38.24%
# Val Loss: 1.5257, Val Accuracy: 44.27%
#
# Epoch: 2
# Train Loss: 1.4081, Train Accuracy: 49.05%
# Val Loss: 1.4128, Val Accuracy: 49.93%
#
# Epoch: 3
# Train Loss: 1.2815, Train Accuracy: 53.92%
# Val Loss: 1.3183, Val Accuracy: 52.88%
#
# Epoch: 4
# Train Loss: 1.2007, Train Accuracy: 56.77%
# Val Loss: 1.2743, Val Accuracy: 54.76%
#
# Epoch: 5
# Train Loss: 1.1327, Train Accuracy: 59.19%
# Val Loss: 1.2160, Val Accuracy: 56.32%
#
# Epoch: 6
# Train Loss: 1.0738, Train Accuracy: 61.23%
# Val Loss: 1.1863, Val Accuracy: 58.37%
#
# Epoch: 7
# Train Loss: 1.0073, Train Accuracy: 63.88%
# Val Loss: 1.1441, Val Accuracy: 59.67%
#
# Epoch: 8
# Train Loss: 0.9596, Train Accuracy: 65.63%
# Val Loss: 1.1594, Val Accuracy: 59.91%
#
# Epoch: 9
# Train Loss: 0.9102, Train Accuracy: 67.33%
# Val Loss: 1.1431, Val Accuracy: 60.78%
#
# Epoch: 10
# Train Loss: 0.8569, Train Accuracy: 69.21%
# Val Loss: 1.1784, Val Accuracy: 60.38%
#
# ...
